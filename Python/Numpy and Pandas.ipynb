# %% [markdown]
# Data Importing - NumPy and Pandas

# %%
#Importing data from flat file - csv
import pandas as pd
csvdata = pd.read_csv("dschools.csv")
csvdata
# Out:
#       Unnamed: 0                        name         phone  \
# 0              0     A. Henderson Elementary  703-670-2885
# 1              1  A.G. Richardson Elementary  540-825-0616
# 2              2       A.M. Davis Elementary  804-674-1310
# 3              3        A.P. Hill Elementary  804-862-7002
# 4              4      A.S. Rhodes Elementary  540-635-4556
# ...          ...                         ...           ...
# 1983        1983         Yorktown Elementary  757-898-0358
# 1984        1984               Yorktown High  703-228-5400
# 1985        1985             Yorktown Middle  757-898-0360
# 1986        1986           Yowell Elementary  540-825-9484
# 1987        1987             Yuma Elementary  276-386-3109
#
#                   principal grades                              division
# 0        Ms. Suzanne Bevans   PK-5  Prince William County Public Schools
# 1     Mrs. Susan E. Bridges   PK-5        Culpeper County Public Schools
# ...

# %%
#Importing data from flat file - Excel
import pandas as pd
excle_data = pd.read_excel("sampled.xls")
excle_data
# Out:
#      0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0    1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1    2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3    4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4    5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# 5    6     Gaston       Brumm    Male  United States   24  21/05/2015  2554
# 6    7       Etta        Hurn  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean      Melgar  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza     Weiland  Female  United States   40  21/05/2015  6548
# 9   10     Fallon     Winward  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia      Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %%
#CONNECTING TO SQL SERVER - Method 1
import pyodbc
con = pyodbc.connect(
        'DRIVER={SQL Server};'
        'SERVER=LAPTOP-0TK9QJEO;'
        'DATABASE=sales_db;'
        'Trusted_Connection=yes;'
    )

# %%
cursor = con.cursor()

# %%
cursor.execute("select * from dbo.Customers")

# %%
cursor.fetchall()
# Out:
# [(101, 'John Doe'),
#  (102, 'Jane Smith'),
#  (103, 'Bob Johnson'),
#  (104, 'Alice Brown'),
#  (105, 'Mary Davis')]

# %%
#Connecting to SQL server - Method 2
import pyodbc
import pandas as pd
con = pyodbc.connect("DRIVER={SQL Server};SERVER=LAPTOP-0TK9QJEO;DATABASE=social_media_db;Trusted_Connection=yes")
dbdf = pd.read_sql_query('Select * from dbo.user_data',con)
dbdf
# Out:
#    User_ID      Account_Name      User_Name  Age  Gender Date_Joined  Posts  \
# 0        1  starlight_dancer   Emma Johnson   28  Female  2020-05-15    120
# 1        2        zen_master  Chris Roberts   30    Male  2019-12-20     80
# 2        3        neon_ninja     Jordan Lee   25   Other  2021-02-10     95
# 3        4      sky_wanderer     Alex Smith   32    Male  2018-11-04    200
# 4        5      sunset_lover   Taylor Brown   27  Female  2017-09-01    150
#
#    Likes  Followers  Following
# 0    450        200        150
# 1    300        150        180
# 2    600        250        220
# 3    900        350        300
# 4    800        400        380

# %%
#Importing data from JSON file
import json
with open('schools.json') as file:
    jsondata = json.load(file)
jsondata
# Out:
# [{'name': 'A. Henderson Elementary',
#   'address': '3799 Waterway Dr, Dumfries, VA 22025',
#   'phone': '703-670-2885',
#   'principal': 'Ms. Suzanne Bevans',
#   'grades': 'PK-5',
#   'division': 'Prince William County Public Schools'},
#  {'name': 'A.G. Richardson Elementary',
#   'address': '18370 Simms Dr, Culpeper, VA 22701',
#   'phone': '540-825-0616',
#   'principal': 'Mrs. Susan E. Bridges',
#   'grades': 'PK-5',
#   'division': 'Culpeper County Public Schools'},
#  {'name': 'A.M. Davis Elementary',
#   'address': '415 S Providence Rd, Richmond, VA 23236-3343',
#   'phone': '804-674-1310',
#   'principal': 'Dr. Rachel Foglesong',
#   'grades': 'PK-5',
#   'division': 'Chesterfield County Public Schools'},
#  {'name': 'A.P. Hill Elementary',
#   'address': '1450 Talley Avenue, Petersburg, VA 23803',
#   'phone': '804-862-7002',
#   'principal': 'Mrs. Kori Reddick',
#   'grades': 'KG-5',
#   'division': 'Petersburg Public Schools'},
#  {'name': 'A.S. Rhodes Elementary',
# ...

# %%
#Loading Data from Open DATASETS with API
import opendatasets as od
opendata = 'https://www.kaggle.com/datasets/aditya0kumar0tiwari/play-badminton'
od.download(opendata)
# Out:
# Skipping, found downloaded files in ".\play-badminton" (use force=True to force download)

# %%
#Loading data from a WEBPAGE
import requests
import pandas as pd
from bs4 import BeautifulSoup
url = 'https://afd.calpoly.edu/web/sample-tables'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
tables =pd.io.html.read_html(url)
tables
# Out:
# [                                         Description  \
#  0                            Academic Senate Meeting
#  1                               Commencement Meeting
#  2                                     Dean's Council
#  3                            Committee on Committees
#  4  Lorem ipsum dolor sit amet, consectetuer adipi...
#  5                                  Lorem ipsum dolor
#
#                                                  Date  \
#  0                                       May 25, 2205
#  1                                  December 15, 2205
#  2                                   February 1, 2206
#  3                                      March 3, 2206
#  4  Lorem ipsum dolor sit amet, consectetuer adipi...
#  5                                  Lorem ipsum dolor
#
#                                              Location
#  0                                 Building 99 Room 1
#  1                                Building 42 Room 10
# ...

# %%
html_text = resp.text
html_text
# Out:
# '<!DOCTYPE html>\r\n<html class="no-js" lang="en" dir="ltr">\r\n\r\n<head>\r\n\t<!--\r\nCal Poly Web Template v2.0.0\r\nCode maintained by\r\nInformation Technology Services\r\nCalifornia Polytechnic State University\r\nSan Luis Obispo, CA 93407\r\n-->\r\n\t<meta charset="UTF-8">\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge">\r\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0"/> \r\n\r\n\t<title>Sample Tables - Web - Cal Poly</title>\n\r\n\t<meta http-equiv="content-language" content="en" />\r\n\t<meta name="language" content="en" />\r\n\t<meta name="msapplication-config" content="none" />\r\n\r\n\t<meta name="codebase" content="AFD-2.0" />\r\n\r\n\r\n\t<meta name="Description" content="As stewards of the University resources, we provide high quality, efficient support and planning services as an integral part of the campus community in support of student learning." />\r\n\t<meta name="Keywords" content="Cal Poly, Administration, AFD, Finance, Polic
# ...

# %%
BeautifulSoup(html_text)
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en">
# <head>
# <!--
# Cal Poly Web Template v2.0.0
# Code maintained by
# Information Technology Services
# California Polytechnic State University
# San Luis Obispo, CA 93407
# -->
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Sample Tables - Web - Cal Poly</title>
# <meta content="en" http-equiv="content-language"/>
# <meta content="en" name="language"/>
# <meta content="none" name="msapplication-config"/>
# <meta content="AFD-2.0" name="codebase"/>
# <meta content="As stewards of the University resources, we provide high quality, efficient support and planning services as an integral part of the campus community in support of student learning." name="Description"/>
# <meta content="Cal Poly, Administration, AFD, Finance, Police, Budget, Facilities, Fiscal, HR, Risk, Technology, Corporation" name="Keywords"/>
# ...

# %% [markdown]
# **Data Cleaning**

# %%
import pandas as pd
import numpy as np
#creating a dataframe using dict
df = pd.DataFrame(data={
    'Temperature':[25,np.nan,34,20,15,19,18,np.nan,25],
    'Humidity':[20,20,12,np.nan,13,15,np.nan,np.nan,20],
    'Situation':['Humid',np.nan, 'Too-Sunny','cool','Too Cool','Normal','Normal',np.nan,'Humid']
})
df
# Out:
#    Temperature  Humidity  Situation
# 0         25.0      20.0      Humid
# 1          NaN      20.0        NaN
# 2         34.0      12.0  Too-Sunny
# 3         20.0       NaN       cool
# 4         15.0      13.0   Too Cool
# 5         19.0      15.0     Normal
# 6         18.0       NaN     Normal
# 7          NaN       NaN        NaN
# 8         25.0      20.0      Humid

# %%
#checking the dataframe for a missing value
df.isna()
# Out:
#    Temperature  Humidity  Situation
# 0        False     False      False
# 1         True     False       True
# 2        False     False      False
# 3        False      True      False
# 4        False     False      False
# 5        False     False      False
# 6        False      True      False
# 7         True      True       True
# 8        False     False      False

# %%
df.isna().sum()
# Out:
# Temperature    2
# Humidity       3
# Situation      2
# dtype: int64

# %%
#using visual approach to check the missing values
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#Deleting missing values anywhere is table
tempdf = df.dropna()
tempdf
# Out:
#    Temperature  Humidity  Situation
# 0         25.0      20.0      Humid
# 2         34.0      12.0  Too-Sunny
# 4         15.0      13.0   Too Cool
# 5         19.0      15.0     Normal
# 8         25.0      20.0      Humid

# %%
#Deleting record which have all missing values
tempdf = df.dropna(how="all")
tempdf
# Out:
#    Temperature  Humidity  Situation
# 0         25.0      20.0      Humid
# 1          NaN      20.0        NaN
# 2         34.0      12.0  Too-Sunny
# 3         20.0       NaN       cool
# 4         15.0      13.0   Too Cool
# 5         19.0      15.0     Normal
# 6         18.0       NaN     Normal
# 8         25.0      20.0      Humid

# %%
#Filling using forward method - Top Down approach
ffill = df.fillna(method="ffill")
ffill
# Out:
#    Temperature  Humidity  Situation
# 0         25.0      20.0      Humid
# 1         25.0      20.0      Humid
# 2         34.0      12.0  Too-Sunny
# 3         20.0      12.0       cool
# 4         15.0      13.0   Too Cool
# 5         19.0      15.0     Normal
# 6         18.0      15.0     Normal
# 7         18.0      15.0     Normal
# 8         25.0      20.0      Humid

# %%
#Filling using backward method - Bottom Top approach
dfill = df.fillna(method="dfill")
dfill
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11080\2794243757.py in <module>
#       1 #Filling using backward method - Bottom Top approach
# ----> 2 dfill = df.fillna(method="dfill")
#       3 dfill
#
# NameError: name 'df' is not defined

# %%
sns.heatmap(ffill.isnull)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41112\540779888.py in <module>
# ----> 1 sns.heatmap(ffill.isnull)
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     446     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 448                           yticklabels, mask)
#     449
#     450     # Add the pcolormesh kwargs here
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
# ...

# %%
#df is my main dataframe
#ffill is the dataframe for forward method
# tempdf is the dataframe for removing whole record with missing values, NaN

# %%
tempdf
# Out:
#    Temperature  Humidity  Situation
# 0         25.0      20.0      Humid
# 1          NaN      20.0        NaN
# 2         34.0      12.0  Too-Sunny
# 3         20.0       NaN       cool
# 4         15.0      13.0   Too Cool
# 5         19.0      15.0     Normal
# 6         18.0       NaN     Normal
# 8         25.0      20.0      Humid

# %%
meanv = tempdf["Temperature"].mean()
meanv
# Out:
# 22.285714285714285

# %%
#to fill and make it parmanent change in the table i.e. tempdf using mean value and inplace = True
tempdf["Temperature"].fillna(meanv, inplace=True)
# Out:
# C:\Users\ajit_\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
tempdf
# Out:
#    Temperature  Humidity  Situation
# 0    25.000000      20.0      Humid
# 1    22.285714      20.0        NaN
# 2    34.000000      12.0  Too-Sunny
# 3    20.000000       NaN       cool
# 4    15.000000      13.0   Too Cool
# 5    19.000000      15.0     Normal
# 6    18.000000       NaN     Normal
# 8    25.000000      20.0      Humid

# %%
meanh = tempdf["Temperature"].mean()
meanh
tempdf["Temperature"].fillna(meanh, inplace=True)
# Out:
# C:\Users\ajit_\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
tempdf
# Out:
#    Temperature  Humidity  Situation
# 0    25.000000      20.0      Humid
# 1    22.285714      20.0        NaN
# 2    34.000000      12.0  Too-Sunny
# 3    20.000000       NaN       cool
# 4    15.000000      13.0   Too Cool
# 5    19.000000      15.0     Normal
# 6    18.000000       NaN     Normal
# 8    25.000000      20.0      Humid

# %%
tempdf.drop_duplicates()
# Out:
#    Temperature  Humidity  Situation
# 0    25.000000      20.0      Humid
# 1    22.285714      20.0        NaN
# 2    34.000000      12.0  Too-Sunny
# 3    20.000000       NaN       cool
# 4    15.000000      13.0   Too Cool
# 5    19.000000      15.0     Normal
# 6    18.000000       NaN     Normal

# %%
#Loading the dataset
dsdata = pd.read_csv("dc_dataset.csv")
dsdata.head()
# Out:
#     ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
dsdata
# Out:
#        ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0     502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 1     735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 2     420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3     680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 4     504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
# ...   ...        ...    ...   ...   ...   ...    ...   ...  ...  ...  ...
# 1004  191     454316      M  55.0   NaN  62.0    6.8   5.3  2.0  1.0  3.5
# 1005  192     454316      M  55.0   4.8  88.0    NaN   5.7  4.0  0.9  3.3
# 1006  193     454316      M  62.0   6.3  82.0    6.7   5.3  2.0  1.0  3.5
# 1007  194     454316      F  57.0   4.1  70.0    9.3   5.3  3.3  1.0  1.4
# 1008  195       4543      f  55.0   4.1  34.0   13.9   5.4  1.6  1.6  3.1
#
#       VLDL   BMI CLASS
# 0      0.5  24.0     N
# 1      0.6  23.0     N
# ...

# %%
dsdata.columns
# Out:
# Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='object')

# %%
dsdata.rename(columns={"No_Pation":"Patient_ID"}, inplace = True)

# %%
#checking duplicates
dsdata.duplicated().sum()
# Out:
# 0

# %%
#checking for missing values
dsdata.isna().sum()
# Out:
# ID            0
# Patient_ID    0
# Gender        0
# AGE           1
# Urea          1
# Cr            2
# HbA1c         3
# Chol          2
# TG            2
# HDL           1
# LDL           2
# VLDL          1
# BMI           0
# CLASS         0
# dtype: int64

# %%
hbmean = dsdata["HbA1c"].mean()

# %%
dsdata["HbA1c"].fillna(hbmean, inplace= True)

# %%
finaldata = dsdata.dropna()

# %%
finaldata.isna().sum()
# Out:
# ID            0
# Patient_ID    0
# Gender        0
# AGE           0
# Urea          0
# Cr            0
# HbA1c         0
# Chol          0
# TG            0
# HDL           0
# LDL           0
# VLDL          0
# BMI           0
# CLASS         0
# dtype: int64

# %% [markdown]
# **OUTLIERS**

# %%
import seaborn as sns
sns.boxplot(finaldata["Urea"])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(finaldata["Cr"])
# Out:
# <AxesSubplot:>

# %%
maxol = finaldata["Cr"].quantile(0.50)
maxol
# Out:
# 60.0

# %%
maxol = finaldata["Cr"].quantile(0.555)
maxol
# Out:
# 62.0

# %%
finaldata["Cr"] > maxol
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1002     True
# 1003    False
# 1005     True
# 1007     True
# 1008    False
# Name: Cr, Length: 997, dtype: bool

# %%
finaldata[finaldata["Cr"]>maxol]
# Out:
#        ID  Patient_ID Gender   AGE  Urea     Cr     HbA1c  Chol   TG  HDL  \
# 8     670       34229      M  43.0   2.6   67.0  4.000000   3.8  0.9  2.4
# 15    566       34236      M  50.0   5.5   74.0  5.000000   3.6  1.1  1.0
# 20     64       34240      F  49.0  13.5  175.0  5.100000   0.5  1.9  1.3
# 21     97       12744      F  42.0   5.0   73.0  4.500000   6.2  1.0  1.1
# 26    494       45566      M  30.0   4.8   80.0  5.500000   5.5  1.8  1.2
# ...   ...         ...    ...   ...   ...    ...       ...   ...  ...  ...
# 997   669       87654      M  30.0   7.1   81.0  6.700000   4.1  1.1  1.2
# 1000  185      454316      M  64.0   8.8  106.0  8.500000   5.9  2.1  1.2
# 1002  188      454316      F  75.0  10.3  113.0  8.600000   4.2  1.6  0.9
# 1005  192      454316      M  55.0   4.8   88.0  8.284155   5.7  4.0  0.9
# 1007  194      454316      F  57.0   4.1   70.0  9.300000   5.3  3.3  1.0
#
#       LDL  VLDL   BMI CLASS
# 8     3.7   1.0  21.0     N
# ...

# %%
myfinaldataset = finaldata[finaldata["Cr"] <= maxol]

# %%
sns.boxplot(x=myfinaldataset["Cr"])
# Out:
# <AxesSubplot:xlabel='Cr'>

# %% [markdown]
# **DATA MANIPULATION**

# %%
import pandas as pd
data = pd.read_csv("homels.csv")
data.head()
# Out:
#                region       state  individuals  family_members  state_pop
# 0  East South Central     Alabama         2570             864    4887681
# 1             Pacific      Alaska         1434             582     735139
# 2            Mountain     Arizona         7259            2606    7158024
# 3  West South Central    Arkansas         2280             432    3009733
# 4             Pacific  California       109008           20964   39461588

# %%
#Identifying number of rows and columns
data.shape
# Out:
# (51, 5)

# %%
#Detailed info about the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   region          51 non-null     object
#  1   state           51 non-null     object
#  2   individuals     51 non-null     int64
#  3   family_members  51 non-null     int64
#  4   state_pop       51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
data1 = data.convert_dtypes()

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   region          51 non-null     string
#  1   state           51 non-null     string
#  2   individuals     51 non-null     Int64
#  3   family_members  51 non-null     Int64
#  4   state_pop       51 non-null     Int64
# dtypes: Int64(3), string(2)
# memory usage: 2.3 KB

# %%
#Using describe you will get Statistical values
data1.describe()
# Out:
#          individuals  family_members     state_pop
# count      51.000000       51.000000  5.100000e+01
# mean     7225.784314     3504.882353  6.405637e+06
# std     15991.025083     7805.411811  7.327258e+06
# min       434.000000       75.000000  5.776010e+05
# 25%      1446.500000      592.000000  1.777414e+06
# 50%      3082.000000     1482.000000  4.461153e+06
# 75%      6781.500000     3196.000000  7.340946e+06
# max    109008.000000    52070.000000  3.946159e+07

# %%
data1.rename(columns={"state_pop":"state_population"}, inplace = True)
data1
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama         2570             864
# 1              Pacific                Alaska         1434             582
# 2             Mountain               Arizona         7259            2606
# 3   West South Central              Arkansas         2280             432
# 4              Pacific            California       109008           20964
# 5             Mountain              Colorado         7607            3250
# 6          New England           Connecticut         2280            1696
# 7       South Atlantic              Delaware          708             374
# 8       South Atlantic  District of Columbia         3770            3134
# 9       South Atlantic               Florida        21443            9587
# 10      South Atlantic               Georgia         6943            2556
# 11             Pacific                Hawaii         4131            2399
# ...

# %%
data1.sort_values("region")
# Out:
#                 region                 state  individuals  family_members  \
# 35  East North Central                  Ohio         6929            3320
# 49  East North Central             Wisconsin         2740            2167
# 22  East North Central              Michigan         5209            3142
# 13  East North Central              Illinois         6752            3891
# 14  East North Central               Indiana         3776            1482
# 0   East South Central               Alabama         2570             864
# 42  East South Central             Tennessee         6139            1744
# 24  East South Central           Mississippi         1024             328
# 17  East South Central              Kentucky         2735             953
# 38        Mid-Atlantic          Pennsylvania         8163            5349
# 32        Mid-Atlantic              New York        39827           52070
# 30        Mid-Atlantic            New Jersey         6048            3350
# ...

# %%
data1.sort_values("region",ascending=False)
# Out:
#                 region                 state  individuals  family_members  \
# 36  West South Central              Oklahoma         2823            1048
# 3   West South Central              Arkansas         2280             432
# 18  West South Central             Louisiana         2540             519
# 43  West South Central                 Texas        19199            6111
# 25  West North Central              Missouri         3776            2107
# 15  West North Central                  Iowa         1711            1038
# 27  West North Central              Nebraska         1745             676
# 23  West North Central             Minnesota         3993            3250
# 41  West North Central          South Dakota          836             323
# 16  West North Central                Kansas         1443             773
# 34  West North Central          North Dakota          467              75
# 8       South Atlantic  District of Columbia         3770            3134
# ...

# %%
#display 2 columns using nested brackets
data1[["region","state"]]
# Out:
#                 region                 state
# 0   East South Central               Alabama
# 1              Pacific                Alaska
# 2             Mountain               Arizona
# 3   West South Central              Arkansas
# 4              Pacific            California
# 5             Mountain              Colorado
# 6          New England           Connecticut
# 7       South Atlantic              Delaware
# 8       South Atlantic  District of Columbia
# 9       South Atlantic               Florida
# 10      South Atlantic               Georgia
# 11             Pacific                Hawaii
# 12            Mountain                 Idaho
# 13  East North Central              Illinois
# 14  East North Central               Indiana
# 15  West North Central                  Iowa
# 16  West North Central                Kansas
# 17  East South Central              Kentucky
# 18  West South Central             Louisiana
# 19         New England                 Maine
# ...

# %%
#On dataframe data1 display family_members records which are > 3000
data1[data1["family_members"] > 3000]
# Out:
#                 region                 state  individuals  family_members  \
# 4              Pacific            California       109008           20964
# 5             Mountain              Colorado         7607            3250
# 8       South Atlantic  District of Columbia         3770            3134
# 9       South Atlantic               Florida        21443            9587
# 13  East North Central              Illinois         6752            3891
# 21         New England         Massachusetts         6811           13257
# 22  East North Central              Michigan         5209            3142
# 23  West North Central             Minnesota         3993            3250
# 30        Mid-Atlantic            New Jersey         6048            3350
# 32        Mid-Atlantic              New York        39827           52070
# 35  East North Central                  Ohio         6929            3320
# 37             Pacific                Oregon        11139            3337
# ...

# %%
#if new dataframe is your final dataset to use for futher analysis
#data1.to_csv("new_homels.csv")

# %%
#Date Time series function
import pandas as pd
apldata = pd.read_excel("aapl.xlsx")
apldata
# Out:
#           Date    Open    High     Low   Close    Volume
# 0   2017-07-07  142.90  144.75  142.90  144.18  19201712
# 1   2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2   2017-07-05  143.69  144.79  142.72  144.09  21569557
# 3   2017-07-03  144.88  145.30  143.10  143.50  14277848
# 4   2017-06-30  144.45  144.96  143.78  144.02  23024107
# ..         ...     ...     ...     ...     ...       ...
# 246 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 247 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 248 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 249 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 250 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 6 columns]

# %%
#Open and read another dataset
apldata = pd.read_excel("aapl.xlsx",parse_dates=["Date"])

# %%
apldata.head()
# Out:
#         Date    Open    High     Low   Close    Volume
# 0 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 1 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 3 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 4 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
apldata.set_index("Date")
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
apldata1 = apldata1 = apldata.set_index("Date")
apldata1
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
apldata1.loc["2017-07"]
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848

# %%
#AVG value for Close column for Jan month
apldata1.loc["2017-01"].Close.mean()
# Out:
# 119.57000000000001

# %%
#AVG value of whole table based on Close coulmn
apldata1.Close.mean()
# Out:
# 125.48749003984062

# %%
#AVG value for every month using M or year is Y or quaterly data use Q in resample
apldata1.Close.resample('M').mean()
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: M, Name: Close, dtype: float64

# %%
#To represent using graph
# %matplotlib inline

# %%
apldata1.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
apldata1.Close.resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
apldata1.Close.resample('Q').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# DATA VISUALISATION - Matplotlib and Seaborn
# #Understanding PLotting
# 1. Basic Plot
# 2. Line Chart - passing Diff Attributes
# 3. Sub Plots
# 4. Dataset - Bar Charts, Pie Charts, Histogram, Scatter Plot, Box Plot, Pair Plot, Count Plot, Joint Plot.. etc.
# 5. HeatMap

# %%
#Basic info to display on a plot
#Titles - heading of the the graph on the axis - Labels

# %%
from matplotlib import pyplot as plt
x = [0,1,2,3,4]
y = [0,10,20,30,40]
plt.plot(x,y)
plt.title("Simple Plot")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
#Highlighting the intersection points
from matplotlib import pyplot as plt
x = [0,1,2,3,4]
y = [0,10,20,30,40]
plt.plot(x,y, marker = "h")
plt.title("Simple Plot")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
#Styling or heading to plot
from matplotlib import pyplot as plt
x = [0,1,2,3,4]
y = [0,10,20,30,40]
plt.plot(x,y, marker = "h", ms=15)
f1 = {"family":"calibri","color":"red","size":"25"}
f2 = {"family":"calibri","color":"green","size":"14"}
plt.title("Simple Plot", fontdict=f1)
plt.xlabel("X-Axis", fontdict=f2)
plt.ylabel("Y-Axis", fontdict=f2)
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
from matplotlib import pyplot as plt
x = [0,1,2,3,4]
y = [0,10,20,30,40]
plt.plot(x,y, marker = "h", ms=15)
f1 = {"family":"calibri","color":"red","size":"25"}
f2 = {"family":"calibri","color":"green","size":"14"}
plt.title("Simple Plot", fontdict=f1)
plt.xlabel("X-Axis", fontdict=f2)
plt.ylabel("Y-Axis", fontdict=f2)
plt.show()

# %%
#Vertical subplot
from matplotlib import pyplot as plt
x = [0,1,2,3,4]
y = [0,10,20,30,40]
y1 = [30,20,40,10,50]
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Sub Plot1")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.subplot(1,2,2)
plt.plot(x,y1)
plt.title("Sub Plot2")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
#Horizontal subplot
from matplotlib import pyplot as plt
x = [0,1,2,3,4]
y = [0,10,20,30,40]
y1 = [30,20,40,10,50]
plt.subplot(2,1,1)
plt.plot(x,y)
plt.title("Sub Plot1")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.subplot(2,1,2)
plt.plot(x,y1)
plt.title("Sub Plot2")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
#Working on the dataset
import pandas as pd
df = pd.read_csv("heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heatmap("heart.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28412\4222042829.py in <module>
# ----> 1 heatmap("heart.csv")
#
# NameError: name 'heatmap' is not defined

# %%
#Histogram
import matplotlib.pyplot as plt
plt.hist(df['age'])
# Out:
# (array([  4.,  39., 109., 125., 120., 205., 219., 149.,  46.,   9.]),
#  array([29. , 33.8, 38.6, 43.4, 48.2, 53. , 57.8, 62.6, 67.4, 72.2, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['age'], edgecolor = "black")
# Out:
# (array([  4.,  39., 109., 125., 120., 205., 219., 149.,  46.,   9.]),
#  array([29. , 33.8, 38.6, 43.4, 48.2, 53. , 57.8, 62.6, 67.4, 72.2, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
#Partition or groups use bin
plt.hist(df['age'], edgecolor = "black", bins = [20,40,60,90])
# Out:
# (array([ 57., 659., 309.]),
#  array([20, 40, 60, 90]),
#  <BarContainer object of 3 artists>)

# %%
#box plot
# 22, 22, 27, 33, 38 -- quartile 1
# 40 - median  -- quartile 2
# 40, 60, 62, 66, 69 -- quartile 3
plt.boxplot(df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19f613e7088>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19f610f8788>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19f61424ec8>],
#  'medians': [<matplotlib.lines.Line2D at 0x19f61416788>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19f61416c48>],
#  'means': []}

# %%
#scatter plot
plt.scatter(df['age'],df['trestbps'])

# %%
#Joint Plot
import seaborn as sns
import matplotlib.pyplot as plt
sns.jointplot(x='age', y='trestbps', data=df)
